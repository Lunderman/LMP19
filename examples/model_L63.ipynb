# %%
import sys
sys.path.insert(0, '../')
import LMP19
import numpy as np
import matplotlib.pyplot as plt

# %%
L63 = LMP19.Models.L63()
theta=[10,28,8/3]

# %%
res = L63.get_data(theta=theta,nSteps=1000,dt=0.01)

# %%
for kk in range(3):
    plt.plot(res[kk])
    plt.show()

# %%
plt.plot(res[0],res[1])
plt.show()
plt.plot(res[1],res[2])
plt.show()
plt.plot(res[0],res[2])
plt.show()

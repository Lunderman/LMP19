# %%
import sys
sys.path.insert(0, '../')
import LMP19
import numpy as np
import matplotlib.pyplot as plt

# %%
nK = 36
nJ = 10
L96 = LMP19.Models.L96_23(nK=nK,nJ=nJ)
[b,c,F,h] = [10,10,10,1]

# %%
res = L96.get_data(theta=[b,c,F,h],nSteps=100,dt=0.001)
X = res[:nK,:]
Y = res[nK:,:]

# %%
from matplotlib.widgets import Slider, Button, RadioButtons
# %matplotlib notebook

theta_X = np.linspace(0, 2*np.pi, nK+1)
theta_Y = np.linspace(0, 2*np.pi, nJ*nK+1)

def signal_X(kk):
    Xplt = [val for val in X[:,int(kk)]]+[X[0,int(kk)]]
    return(Xplt)
def signal_Y(kk):
    Yplt = [val+14 for val in Y[:,int(kk)]]+[Y[0,int(kk)]+14]
    return(Yplt)

fig = plt.figure()
ax = plt.subplot(111, projection='polar')


# Adjust the subplots region to leave some space for the sliders and buttons
fig.subplots_adjust(left=0.25, bottom=0.25)


# Draw the initial plot
# The 'line' variable is used for modifying the line later
[line2] = ax.plot(theta_X,signal_X(-1))
[line1] = ax.plot(theta_X,signal_X(-1),'o')
[line3] = ax.plot(theta_Y,signal_Y(-1))

# Add sliders for tweaking the parameters

# Define an axes area and draw a slider in it
slider_ax  = fig.add_axes([0.25, 0.14, 0.65, 0.02])
slider = Slider(slider_ax, 'time', 0, X.shape[1], valinit=0)

# Define an action for modifying the line when any slider's value changes
def sliders_on_changed(val):
    data_X = signal_X(slider.val)
    data_Y = signal_Y(slider.val)
    ax.set_yticks([])
    ax.set_xticks([])
    line1.set_ydata(data_X)
    line2.set_ydata(data_X)
    line3.set_ydata(data_Y)
    fig.canvas.draw_idle()
slider.on_changed(sliders_on_changed)

# Add a button for resetting the parameters
reset_button_ax = fig.add_axes([0.8, 0.025, 0.1, 0.04])
reset_button = Button(reset_button_ax, 'Reset', hovercolor='0.975')
def reset_button_on_clicked(mouse_event):
    slider.reset()
reset_button.on_clicked(reset_button_on_clicked)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib inline

# %%
plt.imshow(X[:,::100])
plt.show()

# %%
plt.imshow(Y[:,::10])
plt.show()

# %% [markdown]
# # Covariance structure from long run

# %%
res = L96.get_data(theta=[b,c,F,h],nSteps=100000,dt=0.001)
Cov = np.cov(res)
L = L96.get_L(0.5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-f0aaa98027b5> in <module>()
# ----> 1 res = L96.get_data(theta=[b,c,F,h],nSteps=100000,dt=0.001)
#       2 Cov = np.cov(res)
#       3 L = L96.get_L(0.5)
#
# ~/Documents/GitHub/LMP19/LMP19/Models/L96.py in get_data(self, x0, theta, nSteps, dt)
#     127
#     128         for kk in range(1,nSteps):
# --> 129             x_path[:,kk] = self.M(x_path[:,kk-1],theta=theta,dt=dt)
#     130
#     131         return(x_path)
#
# ~/Documents/GitHub/LMP19/LMP19/Models/L96.py in M(self, x, theta, dt)
#     111
#     112     def M(self,x,theta=[10,10,10,1],dt=0.001):
# --> 113         return(RK4(x,self.f,dt,theta))
#     114
#     115     def get_data(self,x0=None,theta=[10,10,10,1],nSteps = 500,dt=0.001):
#
# ~/Documents/GitHub/LMP19/LMP19/RK.py in RK4(x, f, dt, args)
#       4     X_k2 = f(x+dt*X_k1/2,args)
#       5     X_k3 = f(x+dt*X_k2/2,args)
# ----> 6     X_k4 = f(x+dt*X_k3,args)
#       7
#       8     X = x+dt*(X_k1+2*X_k2+2*X_k3+X_k4)/6
#
# ~/Documents/GitHub/LMP19/LMP19/Models/L96.py in f(self, x, theta)
#     104
#     105         for kk in range(self.nK):
# --> 106             dX[kk] = -X[(kk-1)%self.nK]*(X[(kk-2)%self.nK]-X[(kk+1)%self.nK])-X[kk]-h*c*np.sum(Y[kk*self.nJ:(kk+1)*self.nJ])/b+F
#     107             for jj in range(kk*self.nJ,(kk+1)*self.nJ):
#     108                 dY[jj]= -c*b*Y[(jj+1)%(self.nJ*self.nK)]*(Y[(jj+2)%(self.nJ*self.nK)]-Y[(jj-1)%(self.nJ*self.nK)])-c*Y[jj]+c*h*X[kk]/b
#
# /Applications/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py in sum(a, axis, dtype, out, keepdims, initial)
#    2074
#    2075     return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
# -> 2076                           initial=initial)
#    2077
#    2078
#
# /Applications/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      84                 return reduction(axis=axis, out=out, **passkwargs)
#      85
# ---> 86     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      87
#      88
#
# KeyboardInterrupt:

# %%
plt.imshow(L)
plt.show()

# %%
plt.imshow(Cov[:L96.nK,:L96.nK])
plt.colorbar()
plt.show()
plt.imshow(L[:L96.nK,:L96.nK])
plt.colorbar()
plt.show()

plt.imshow(Cov[:L96.nK,L96.nK:])
plt.colorbar()
plt.show()
plt.imshow(L[:L96.nK,L96.nK:])
plt.colorbar()
plt.show()

plt.imshow(Cov[L96.nK:,L96.nK:])
plt.colorbar()
plt.show()
plt.imshow(L[L96.nK:,L96.nK:])
plt.colorbar()
plt.show()

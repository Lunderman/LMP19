# %%
import sys
sys.path.insert(0, '/Users/lunderman/Documents/GitHub/LMP19')
import LMP19
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

from sklearn.gaussian_process import GaussianProcessRegressor as GPR
from sklearn.gaussian_process.kernels import RBF,WhiteKernel

# %%
gamma = [-1,-1]
FuQu = LMP19.Models.FuQu(gamma).eval
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-cf13af6be991> in <module>()
#       2 FuQu = LMP19.Models.FuQu(gamma).eval
#       3
# ----> 4 yy = func(xx).reshape((200,200))
#
# NameError: name 'xx' is not defined

# %%
lb , ub = [-10,-10],[10,10]
bounds = np.array([lb,ub]).T
dt = 0.1

xx_mesh = np.meshgrid(np.arange(lb[0],ub[0],dt),np.arange(lb[1],ub[1],dt))
xx = np.vstack([xx_mesh[0].ravel(), xx_mesh[1].ravel()])
yy = func(xx).reshape((200,200))

plt.imshow(yy,origin='lower')
plt.colorbar()
plt.show()

# %%
nPts = 10
X = np.random.uniform(lb,ub,(nPts,2))
y = func(X).reshape((nPts,1))

# %%
GBO = LMP19.GBO(func,2,X,y,bounds)

kernel = 1.0**2*RBF(np.max(np.diag(np.cov(X.T))))+1.0**2*WhiteKernel(np.std(y))
GP = GPR(kernel = kernel,normalize_y=False,n_restarts_optimizer=50).fit(X,y)

# %%
Y = GP.predict(xx.T).reshape((200,200))

vmin ,vmax = np.min(yy),np.max(yy)
plt.imshow(yy,origin='lower',vmin=vmin,vmax=vmax)
plt.colorbar()
plt.show()
plt.imshow(Y,origin='lower',vmin=vmin,vmax=vmax)
plt.colorbar()
plt.show()

ax = plt.axes(projection='3d')
ax.plot_surface(xx_mesh[0], xx_mesh[1], yy, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none',vmin=vmin,vmax=vmax)
plt.show()
ax = plt.axes(projection='3d')
ax.plot_surface(xx_mesh[0], xx_mesh[1], Y, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none',vmin=vmin,vmax=vmax)
plt.show()

# %%
nSteps = 50
for kk in range(nSteps):
    GBO.GP = GP
    GBO.Expected_Improvement()
    if kk%10 ==0:
        print('=============================================')
        print('=============================================')
        print('Step ',kk)
        print('      Selected EI Maximizer: ',GBO.X[-1,:],-GBO.EI(GBO.X[-1,:]))
        print(' Current function maximizer: ',GBO.X[np.argmax(GBO.y),:],np.max(GBO.y))
# Out:
# =============================================
# =============================================
# Step  0
#       Selected EI Maximizer:  [-1.79266852 -0.44356729] 15.212192501399853
#  Current function maximizer:  [0.44995387 1.74015845] -1.932800357662675
# /Applications/anaconda3/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:335: UserWarning: Predicted variances smaller than 0. Setting those variances to 0.
#   warnings.warn("Predicted variances smaller than 0. "
# /Users/lunderman/Documents/GitHub/LMP19/LMP19/Estimation/GBO.py:42: RuntimeWarning: divide by zero encountered in true_divide
#   return(-(((mu_x - f_star)*norm.cdf((mu_x-f_star)/std_x)+
# /Users/lunderman/Documents/GitHub/LMP19/LMP19/Estimation/GBO.py:43: RuntimeWarning: divide by zero encountered in true_divide
#   std_x*norm.pdf((mu_x-f_star)/std_x))[0,0]))
# =============================================
# =============================================
# Step  10
#       Selected EI Maximizer:  [-0.28859136  0.08798905] 0.009527466347398296
#  Current function maximizer:  [-0.28858809  0.08798571] -0.1610678686087692
# /Applications/anaconda3/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0
 'nit': 13, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# /Applications/anaconda3/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.05810215,  0.17504958,  3.00611636,  3.00611636]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 71, 'nit': 15, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# /Applications/anaconda3/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([0.07387834, 0.02318644, 3.0042851 , 3.0042851 ]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 84, 'nit': 25, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# /Applications/anaconda3/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 0.12009987, -0.2145415 ,  3.0160801 ,  3.0160801 ]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 123, 'nit': 26, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# /Applications/anaconda3/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([0.33074375, 0.08868214, 3.00383527, 3.00383527]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 81, 'nit': 12, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# /Applications/anaconda3/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.0924925 ,  0.41827905,  3.00619276,  3.00619276]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 112, 'nit': 13, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# /Applications/anaconda3/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.06544412,  0.00867871,  3.00318193,  3.00318193]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 60, 'nit': 10, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# /Applications/anaconda3/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([0.08262354, 0.07360913, 3.00471299, 3.00471299]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 99, 'nit': 13, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# /Applications/anaconda3/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 2.27178221e-03, -7.37146927e-02,  3.00450040e+00,  3.00450040e+00]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 117, 'nit': 19, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# /Applications/anaconda3/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([0.25143528, 0.46904137, 3.00196673, 3.00196673]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 87, 'nit': 13, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# /Applications/anaconda3/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([  7.72966322, -39.12324316,   3.00726069,   3.00726069]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 95, 'nit': 16, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# /Applications/anaconda3/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 15.93167225, -13.57449569,   2.0522928 ,   2.0522928 ]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 57, 'nit': 10, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# /Applications/anaconda3/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-5.25597685e-03, -2.05067768e-03,  3.00615668e+00,  3.00615668e+00]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 125, 'nit': 19, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# /Applications/anaconda3/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([  9.73325007, -63.09273367,   5.86906149,   5.86906149]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 64, 'nit': 5, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# /Applications/anaconda3/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([0.17366093, 0.20215577, 2.99855778, 2.99855778]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 75, 'nit': 11, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# /Applications/anaconda3/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.13178161, -1.88403402,  3.00313412,  3.00313412]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 137, 'nit': 18, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# /Applications/anaconda3/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 0.01006392, -0.03808362,  3.00179817,  3.00179817]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 95, 'nit': 16, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# /Applications/anaconda3/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.01464037, -0.00560013,  3.00663305,  3.00663305]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 143, 'nit': 20, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# /Applications/anaconda3/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.08613597, -1.01482591,  3.00577969,  3.00577969]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 106, 'nit': 15, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# /Applications/anaconda3/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.34429724, -0.95888586,  3.0036902 ,  3.0036902 ]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 101, 'nit': 11, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# /Applications/anaconda3/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.01307052, -0.01406387,  3.00653452,  3.00653452]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 147, 'nit': 30, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# /Applications/anaconda3/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 0.05789138, -0.43169251,  3.00364998,  3.00364998]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 64, 'nit': 19, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# /Applications/anaconda3/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 15.66125843, -27.81089789,   3.08950406,   3.08950406]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 84, 'nit': 11, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# /Applications/anaconda3/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([2.14070772e-03, 1.07641933e-02, 3.00717836e+00, 3.00717836e+00]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 82, 'nit': 13, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# /Applications/anaconda3/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-7.28191530e-03,  1.49576026e-03,  3.00685609e+00,  3.00685609e+00]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 123, 'nit': 14, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# /Applications/anaconda3/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.33377045,  1.65657231,  2.99806479,  2.99806479]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 86, 'nit': 20, 'warnflag': 2}
#   " state: %s" % convergence_dict)

# %%
Y = GP.predict(xx.T).reshape((200,200))

vmin ,vmax = np.min(yy),np.max(yy)
plt.imshow(yy,origin='lower',vmin=vmin,vmax=vmax)
plt.colorbar()
plt.show()
plt.imshow(Y,origin='lower',vmin=vmin,vmax=vmax)
plt.colorbar()
plt.show()

ax = plt.axes(projection='3d')
ax.plot_surface(xx_mesh[0], xx_mesh[1], yy, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none',vmin=vmin,vmax=vmax)
plt.show()
ax = plt.axes(projection='3d')
ax.plot_surface(xx_mesh[0], xx_mesh[1], Y, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none',vmin=vmin,vmax=vmax)
plt.show()

# %%
plt.plot(np.arange(nSteps),[np.max(GBO.y[:nPts+kk,0]) for kk in range(nSteps)])
plt.ylabel('Max y value')
plt.xlabel('Iteration')
plt.show()

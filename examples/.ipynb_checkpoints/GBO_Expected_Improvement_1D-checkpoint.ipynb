# %%
import sys
sys.path.insert(0, '/Users/lunderman/Documents/GitHub/LMP19')
import LMP19
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

from sklearn.gaussian_process import GaussianProcessRegressor as GPR
from sklearn.gaussian_process.kernels import RBF,WhiteKernel

# %%
gamma = [5]
func = LMP19.Models.FuQu(gamma).eval

# %%
lb , ub = -10,10
bounds = [[lb,ub]]
dt = 0.1

xx = np.arange(lb,ub,dt)
xx = xx.reshape((len(xx),1))
yy= func(xx)

nPts = 5
X = np.array([-9,-7,-6.5,6,8])
X = X.reshape((nPts,1))
y = func(X)
plt.plot(xx,yy)
plt.plot(X,y,'o')
plt.show()

# %%
# Define GP
GP = GPR(kernel = 1.0**2*RBF(np.var(X))+WhiteKernel(0.5*np.std(y),noise_level_bounds='fixed'),normalize_y=True,n_restarts_optimizer=50).fit(X,y)

# View GP
Y_hat,sigma = GP.predict(xx,return_std=True)
plt.fill_between(np.ravel(xx),np.ravel(Y_hat)-2*sigma,np.ravel(Y_hat)+2*sigma,alpha=0.2)
plt.plot(xx,np.ravel(Y_hat),color='C2')
plt.plot(X,y,'o',color='C1')
plt.plot(xx,yy,color='C0')
plt.show()

# %%
# Initialize the GBO Object
GBO = LMP19.Estimation.GBO(func,1,X,y,bounds)

# %%
# Run GBO for set number of iterations
nSteps = 10
ii = np.argmax(GBO.y)
s=7
for kk in range(nSteps):
    GBO.GP = GPR(kernel = 1.0**2*RBF(np.var(GBO.X))+WhiteKernel(0.5*np.std(GBO.y),noise_level_bounds='fixed'),normalize_y=True,n_restarts_optimizer=50).fit(X,y)
    GBO.Expected_Improvement()
    print('=============================================')
    print('=============================================')
    print('Step ',kk)
    EI_yy = []
    for val in xx:
        EI_yy.append(-GBO.EI(val))
    plt.plot(xx,EI_yy,color='C3')
    plt.plot(GBO.X[-1,:],-GBO.EI(GBO.X[-1,:]),'o',color='C2',label='Selected Maximizer')

    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.title('Expected Improvement')
    plt.show()
    
    Y_hat,sigma = GBO.GP.predict(xx,return_std=True)
    plt.fill_between(np.ravel(xx),np.ravel(Y_hat)-2*sigma,np.ravel(Y_hat)+2*sigma,alpha=0.2)
    plt.plot(xx,np.ravel(Y_hat),color='C3')
    plt.plot(xx,yy,color='C0',label='Truth')
    plt.plot(GBO.X[:-1,:],GBO.y[:-1,:],'o',color='C1',label='Observations')
    plt.plot(GBO.X[-1,:],GBO.y[-1,:],'o',color='C2',label='EI Maximizer')
    
    tmp = np.argmax(GBO.y)
    if tmp == ii:
        s += 2
    else:
        ii = tmp
        s = 7
    
    plt.plot(GBO.X[ii,:],GBO.y[ii,0],'o',markersize=s,color='C3',label='Maximizer')
    plt.title('Gaussian Process')
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.show()
# Out:
# =============================================
# =============================================
# Step  0
# =============================================
# =============================================
# Step  1
# =============================================
# =============================================
# Step  2
# =============================================
# =============================================
# Step  3
# =============================================
# =============================================
# Step  4
# =============================================
# =============================================
# Step  5
# =============================================
# =============================================
# Step  6
# =============================================
# =============================================
# Step  7
# =============================================
# =============================================
# Step  8
# =============================================
# =============================================
# Step  9

# %%
GBO.GP.kernel_
# Out:
# 64.4**2 * RBF(length_scale=5.88) + WhiteKernel(noise_level=12.4)

# %%
plt.plot(np.arange(nSteps),[np.max(GBO.y[:nPts+kk,0]) for kk in range(nSteps)])
plt.ylabel('Max y value')
plt.xlabel('Iteration')
plt.show()
